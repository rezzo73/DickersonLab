# %%
# connect to redcap (note: exporting means retrieving from redcap; importing means uploading to redcap)

from redcap import Project, RedcapError

api_url = 'https://redcap.partners.org/redcap/api/'
api_key = '9D668EE32160684D980CD6A95B23CC5B'
# to set specific certificate pathway: verify_ssl='path/to/CA_bundle/' or set to False to ignore SSH verification altogether
project = Project(api_url, api_key) # pycap verifies SSL certificate under the hood (using requests)

##
ids_of_interest = ['1']
fields_of_interest = ['sex','notes']
                    
# will return a list of dicts from all record IDs with all raw field names as keys
data = project.export_records(format='df')

#subset = project.export_records(records=ids_of_interest, fields=fields_of_interest,format='df')

# %%
data
# Out:
#            redcap_repeat_instrument  redcap_repeat_instance  sex  group  \
# record_id
# 1                               NaN                     NaN    0    NaN
# 2                               NaN                     NaN    0    0.0
#
#                                               notes  scan_date  age  \
# record_id
# 1          Delete with subjectID. Used for testing.        NaN  NaN
# 2                                               NaN        NaN  NaN
#
#            download_date  xnat_upload  dicom_path           ...            \
# record_id                                                   ...
# 1                    NaN          NaN         NaN           ...
# 2                    NaN          NaN         NaN           ...
#
#            qc_status  qc_notes  scan_date_test age_test  download_date_test  \
# record_id
# 1                NaN       NaN      2019-01-15      0.0          2019-01-15
# 2                NaN       NaN             NaN      NaN                 NaN
#
# ...

# %%
# import data

# NOTES ON IMPORTING DATA:
# Will overwrite fields (searches all instruments); sex (F == 0 ; M ==1)
# You are not allowed to import data if field appears > 1x (across different instruments)
# Will create the subjectID if not already there
to_import = [{'record_id': '2', 'sex':0, 'group': 0}] # Does record ID have to preexist?
response = project.import_records(to_import)

# %%
# for now, need to make the instruments by importing an excel doc

# %%
# i'm not what this does?

def increment_score(record):
    record['score'] += 5
    
data = project.export_records(fields=['score']) # I think must be a field that exists.
map(increment_score, data)
response = project.import_records(data)

# %%
# instead, return list of select record IDs with all field names
ids_or_interest = ['1','2', '3']
subset = project.export_records(records=ids_of_interest)

# known fields of interest (can combine with above)
fields_of_interest = ['age', 'test_score1','test_score2']
subset = project.export_records(fields=fields_of_interest)

# # only want the first 2 forms #all records / all fields within the first 2 forms
# forms = project.forms[:2]
# subset = project.export_records(forms=forms)

## tweak how the data is formatted
#data = project.export_records(raw_or_label='label') # make the keys the field labels

# Get data in csv
csv_data = project.export_records(format='csv')
dataframe = project.export_records(format='df')
other_df = project.export_records(format='df'. df_kwargs={'index_col':project.field_names[1]})

# export checkbox fields as labels; note you will still have to set raw_or_label to 'label'
data = project.export_records(raw_or_label='label', export_checkbox_labels=True)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/redcap/project.py in configure(self)
#      56         try:
# ---> 57             self.metadata = self.__md()
#      58         except RequestException:
#
# ~/.local/lib/python3.6/site-packages/redcap/project.py in __md(self)
#      92         p_l['content'] = 'metadata'
# ---> 93         return self._call_api(p_l, 'metadata')[0]
#      94
#
# ~/.local/lib/python3.6/site-packages/redcap/project.py in _call_api(self, payload, typpe, **kwargs)
#     154         rcr = RCRequest(self.url, payload, typpe)
# --> 155         return rcr.execute(**request_kwargs)
#     156
#
# ~/.local/lib/python3.6/site-packages/redcap/request.py in execute(self, **kwargs)
#     122         """
# --> 123         r = post(self.url, data=self.payload, **kwargs)
#     124         # Raise if we need to
#
# ...
