# %%
import nipype

nipype.test(doctests=False)
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.6, pytest-3.6.4, py-1.5.4, pluggy-0.6.0
# rootdir: /homes/2/rje11/.local/lib/python3.6/site-packages/nipype, inifile: pytest.ini
# plugins: xdist-1.24.1, forked-0.2, remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2
# gw0 I / gw1 I / gw2 I / gw3 I / gw4 I / gw5 I / gw6 I / gw7 I / gw8 I / gw9 I / gw10 I / gw11 I
# gw0 [2172] / gw1 [2172] / gw2 [2172] / gw3 [2172] / gw4 [2172] / gw5 [2172] / gw6 [2172] / gw7 [2172] / gw8 [2172] / gw9 [2172] / gw10 [2172] / gw11 [2172]
#
# scheduling tests via LoadScheduling
# ..............................................s......................... [  3%]
# ........................................................................ [  6%]
# ......................................................................... [  9%]
# ......................................................................s. [ 13%]
# ...
