# %%
import pandas as pd

t2_path_right = '/autofs/cluster/animal/scan_data/leads/recon_test/T2/aparc_stats_r.txt'

t2_path_left = '/autofs/cluster/animal/scan_data/leads/recon_test/T2/aparc_stats_l.txt'

flair_path_right = '/autofs/cluster/animal/scan_data/leads/recon_test/FLAIR/aparc_stats_r.txt'

flair_path_left = '/autofs/cluster/animal/scan_data/leads/recon_test/FLAIR/aparc_stats_l.txt'

# %%
t2right = pd.read_csv(t2_path_right, sep='\t',index_col=0, header=None)

# %%
t2right
# Out:
#                              1                                2   \
# 0
# rh.aparc.area  rh_bankssts_area  rh_caudalanteriorcingulate_area
# LDS0370001_t2             835.0                            572.0
# LDS0370007_t2             766.0                            351.0
# LDS3600030_t2             586.0                            719.0
# LDS9410023_t2             770.0                            617.0
# LDS9410049_t2             864.0                            635.0
#
#                                         3               4   \
# 0
# rh.aparc.area  rh_caudalmiddlefrontal_area  rh_cuneus_area
# LDS0370001_t2                       2172.0          1623.0
# LDS0370007_t2                       1591.0          1161.0
# LDS3600030_t2                       1431.0          1351.0
# LDS9410023_t2                       2269.0          1330.0
# LDS9410049_t2                       1742.0          1176.0
#
#                                5                 6                         7   \
# ...
